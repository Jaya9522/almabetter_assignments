# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaya9522/almabetter_assignments/blob/main/Assignment_Vector_Algebra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Complete these problems by hand in a piece of paper and then upload in a text cell.**

# %% [markdown]
# # Problem 1

# %% [markdown]
# <b>The vector $\vec{v}$
# =
# ⟨
# 4
# ,
# −
# 2
# ,
# 1
# ⟩
#  ends at the point
# P
# =
# (
# 7
# ,
# −
# 7
# ,
# 2
# )
# . At what point does the vector start? </b>

# %% [markdown]
# ![WhatsApp Image 2022-07-02 at 9.52.46 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # Problem 2

# %% [markdown]
# <b>Check if the position vector formed by $ r = (cosθ,sinθ)$ is a unit vector. Assume (0,0) as the origin. </b>
# .

# %% [markdown]
# ![WhatsApp Image 2022-07-02 at 9.52.45 PM (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # Problem 3

# %% [markdown]
# <b>Find a vector that points in the opposite direction as $\vec{a}$
# =
# ⟨
# −
# 3
# ,
# −
# 14
# ,
# 2
# ⟩
#  with a magnitude of 32.</b>

# %% [markdown]
# ![WhatsApp Image 2022-07-02 at 9.52.45 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2022-07-02 at 9.52.44 PM (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # Problem 4

# %% [markdown]
# <b>Given that  $\vec{a}.\vec{b} = 6 , \Vert{a}\Vert = 4.3$  and the angle between $\vec{a} $ and $\vec{b}$ is $\frac{\pi}{6}$, determine if $\vec{b}$ is a unit vector or not. </b>

# %% [markdown]
# ![WhatsApp Image 2022-07-02 at 9.52.44 PM.jpeg](data:image/jpeg;base64,...)
