# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaya9522/almabetter_assignments/blob/main/Assignment_Sampling_%26_Statistical_Inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #<u> Problem 1

# %% [markdown]
# ![Screenshot 2020-11-30 at 5.25.55 PM.png](data:image/png;base64,...)

# %% [markdown]
# P(X<35)=P(Z<
# 12/
# 50
# ​
#
# 35−40
# ​
#  )
# \approx P(Z<-2.9463)\approx0.0016≈P(Z<−2.9463)≈0.0016

# %% [markdown]
# #<u> Problem 2 </u>

# %% [markdown]
# ![Screenshot 2020-11-30 at 5.27.19 PM.png](data:image/png;base64,...)

# %% [markdown]
# # <u>Problem 3

# %% [markdown]
# ![Screenshot 2020-11-30 at 5.28.32 PM.png](data:image/png;base64,...)

# %% [markdown]
# # <u>Problem 4

# %% [markdown]
# ![Screenshot 2020-11-30 at 5.29.19 PM.png](data:image/png;base64,...)
