# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaya9522/almabetter_assignments/blob/main/Competetive_Coding_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Time : 1 hour
#
# # Problem Statement

# %% [markdown]
# You are given a string containing characters A and B only. Your task is to change it into a string such that there are no matching adjacent characters. To do this, you are allowed to delete zero or more characters in the string.
#
# Your task is to find the minimum number of required deletions.

# %% [markdown]
# **Example**
#
# <code>s = AABAAB</code>
#
# Remove an A at positions 0 and 3 to make <code>s = ABAB</code> in 2 deletions.

# %% [markdown]
# ## **Function Description**
#
# ### Create a <code>alternatingCharacters</code> function below.
#
# ### **Inputs:**
#
# ### string s: a string
#
# ### **Output:**
#
# ### int: the minimum number of deletions required

# %% [markdown]
# # Examples
#
# AAAA : 3 deletions
#
# BBBBB : 4 deletions
#
# ABABABAB : 0 deletions
#
# BABABA : 0 deletions
#
# AAABBB : 4 deletions

# %% [markdown]
# # Explanation
#
# The characters marked red are the ones that can be deleted so that the string does not have matching adjacent characters.
#
# ![Screenshot 2021-02-20 at 12.49.10 PM.png](data:image/png;base64,...)

# %% [markdown]
# # Solution

# %%
import math
import os
import random
import re
import sys

# %%
def alternatingcharacters(s):
  c=0
  for i in range(1,len(s)):
    if s[i]==s[i-1]:
      c+=1
  return c

# %%
if __name__ == '__main__':
    fptr = sys.stdout   # stdout is already an open stream

    q = int(input().strip())

    for q_itr in range(q):
        s = input()

        result = alternatingcharacters(s)

        fptr.write(str(result) + '\n')

    fptr.close()
# Out:
# 113
# AA
# 1
# BBB
# 2
# AABB
# 2
# GGG
# 2
