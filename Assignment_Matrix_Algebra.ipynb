# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaya9522/almabetter_assignments/blob/main/Assignment_Matrix_Algebra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Complete these problems by hand in a piece of paper and then upload in a text cell.**

# %% [markdown]
# # Problem 1

# %% [markdown]
# Find the inverse of the following matrix :
# \begin{bmatrix}
# 2 & 1 & 2\\
# 1 & 2 & 1\\
# 3 & 1 & 3
# \end{bmatrix}

# %% [markdown]
# ![WhatsApp Image 2022-07-03 at 12.17.27 AM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # Problem 2

# %% [markdown]
# Given a matrix \begin{bmatrix}
# 2 & 0 & 0\\
# 0 & 1 & 0\\
# 0 & 0 & 5
# \end{bmatrix}
#
# find it's eigenvalues.

# %% [markdown]
# ![WhatsApp Image 2022-07-03 at 12.17.27 AM (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # Problem 3

# %% [markdown]
# You are given three matrices A,B,C respectively
# \begin{bmatrix}
# 1 & 0 & -1 & 2\\
# 0 & 3 & 1 & -1\\
# 2 & 4 & 0 & 3\\
# -3 & 1 & 2 & 4
# \end{bmatrix}
#
# \begin{bmatrix}
# 1 & 2 \\
# 3 & -1\\
# 0 & -1\\
# 4 & 2
# \end{bmatrix}
#
# \begin{bmatrix}
# 3 & 8 & 0 & 5\\
# 1 & 0 & -4 & 8
# \end{bmatrix}
#
# Consider another matrix $D = CAB $ if it exists. Find the value of $D_{22}$

# %% [markdown]
# ![WhatsApp Image 2022-07-03 at 12.15.24 AM.jpeg](data:image/jpeg;base64,...)
