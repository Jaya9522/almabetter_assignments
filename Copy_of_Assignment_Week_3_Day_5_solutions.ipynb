# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaya9522/almabetter_assignments/blob/main/Copy_of_Assignment_Week_3_Day_5_solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MATH**

# %% [markdown]
# ## 1. Suppose the number of customers arriving at a store obeys a Poisson distribution with an average of λ customers per unit time. That is, if Y is the number of customers arriving in an interval of length t, then Y∼Poisson(λt). Suppose that the store opens at time t=0. Let X be the arrival time of the first customer. Show that X∼Exponential(λ).

# %% [markdown]
# ![WhatsApp Image 2022-10-21 at 19.12.49.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 2. Let X be a random variable with PDF given by
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![WhatsApp Image 2022-10-21 at 19.12.50.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2022-10-21 at 19.13.28.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 3. Let X and Y be jointly continuous random variables with joint PDF
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![WhatsApp Image 2022-10-21 at 19.13.28 (2).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2022-10-21 at 19.13.28 (3).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 4. Let X and Y be two independent discrete random variables with the same CDFs FX and FY .
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![WhatsApp Image 2022-10-21 at 19.13.28 (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # **MACHINE LEARNING**

# %% [markdown]
# ## 1. a. What are the ways to avoid the problem of initialization sensitivity in the K means Algorithm?
#
# ## b. How to decide the optimal number of K in the K means Algorithm?

# %% [markdown]
# **What are the ways to avoid the problem of initialization sensitivity in the K means Algorithm?**
#
# **Repeat K means**: It basically repeats the algorithm again and again along with initializing the centroids followed by picking up the cluster which results in the small intracluster distance and large intercluster distance.
#
# **K Means++**: It is a smart centroid initialization technique.
# Amongst the above two techniques, K-Means++ is the best approach.

# %% [markdown]
# **How to decide the optimal number of K in the K means Algorithm**
#
# There is a popular method known as elbow method which is used to determine the optimal value of K to perform the K-Means Clustering Algorithm. The basic idea behind this method is that it plots the various values of cost with changing k. As the value of K increases, there will be fewer elements in the cluster. So average distortion will decrease. The lesser number of elements means closer to the centroid. So, the point where this distortion declines the most is the elbow point.

# %% [markdown]
# ## 2. a. What is the Objective Function of k-Means?
#
# ## b. How would you perform k-Means on very large datasets?

# %% [markdown]
# **What is the Objective Function of k-Means**
#
# n K-means, the optimization criterion is to minimize the total squared error between the training samples and their representative prototypes. This is equivalent to minimizing the trace of the pooled within covariance matrix.
#
# ![Screenshot (68).png](data:image/png;base64,...)

# %% [markdown]
# **2.b**
#
# K-Means which is one of the most used clustering methods and K-Means based on MapReduce is considered as an advanced solution for very large dataset clustering. However, the executing time is still an obstacle due to the increasing number of iterations when there is an increase of dataset size and number of clusters
#
# The whole idea is to split data intelligently in such a way that you can perform the whole kmeans computation on split data and then combine results to form final clusters and centroids. The implementation is possible as I have shared code and implementation, but you need to test on your machine and see whether it works for you or not.
# In general Apache Mahout implementation of KMeans Scalable machine learning and data mining is made to work on map reduce paradigm. It does work on distributed data(split data in your case) to produce final clusters and centroids.
#
# Since you have 20GB text file, the other challenge is to do feature engineering. You can't just use the whole text corpus to do Kmeans. you need to apply some preprocessing algorithm to do important feature extraction and then apply kmeans over that. I am assuming you are creating a term-document matrix of whole corpus with TF-IDF as weighting and distance metric. If not, then do this first and then think about kmeans.
# To create such huge matrix and do computation such as term-document,tfidf and kmeans, you can use a general BSP framework on top of Hadoop

# %% [markdown]
# ## 3. a. Explain the different linkage methods used in the Hierarchical Clustering Algorithm.
#
# ## b. List down the pros and cons of complete and single linkages methods in the Hierarchical Clustering Algorithm.

# %% [markdown]
# **3.a**
#
# The process of Hierarchical Clustering involves either clustering sub-clusters(data points in the first iteration) into larger clusters in a bottom-up manner or dividing a larger cluster into smaller sub-clusters in a top-down manner. During both the types of hierarchical clustering, the distance between two sub-clusters needs to be computed. The different types of linkages describe the different approaches to measure the distance between two sub-clusters of data points. The different types of linkages are:-
# 1. Single Linkage: For two clusters R and S, the single linkage returns the minimum distance between two points i and j such that i belongs to R and j belongs to S.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![single2.png](data:image/png;base64,...)

# %% [markdown]
# 2. Complete Linkage: For two clusters R and S, the complete linkage returns the maximum distance between two points i and j such that i belongs to R and j belongs to S.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![complete5.png](data:image/png;base64,...)

# %% [markdown]
# 3. Average Linkage: For two clusters R and S, first for the distance between any data-point i in R and any data-point j in S and then the arithmetic mean of these distances are calculated. Average Linkage returns this value of the arithmetic mean.
#
# n_{R} – Number of data-points in R
#
# n_{S} – Number of data-points in S
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![average1.png](data:image/png;base64,...)

# %% [markdown]
# Write your answer here.

# %% [markdown]
# ## 4. a. What is a dendrogram in Hierarchical Clustering Algorithm?
#
# ## b. Explain the different parts of dendrograms in the Hierarchical Clustering Algorithm.

# %% [markdown]
# **What is a dendrogram in Hierarchical Clustering Algorithm**
#
# A dendrogram is a diagram that shows the hierarchical relationship between objects. It is most commonly created as an output from hierarchical clustering. The main use of a dendrogram is to work out the best way to allocate objects to clusters. The dendrogram below shows the hierarchical clustering of six observations shown on the scatterplot to the left. (Dendrogram is often miswritten as dendogram.)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Explain the different parts of dendrograms in the Hierarchical Clustering Algorithm**
#
# A dendrogram is a type of tree diagram showing hierarchical clustering — relationships between similar sets of data. They are frequently used in biology to show clustering between genes or samples, but they can represent any type of grouped data.
#
# Parts of a Dendrogram
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# A dendrogram can be a column graph (as in the image below) or a row graph. Some dendograms are circular or have a fluid-shape, but software will usually produce a row or column graph. No matter what the shape, the basic graph comprises of the same parts:
#
# The clade is the branch. Usually labeled with Greek letters from left to right (e.g. α β, δ…).
# Each clade has one or more leaves. The leaves in the above image are:
# Single (simplicifolius): F
# Double (bifolius): D E
# Triple (trifolious): A B C
# A clade can theoretically have an infinite amount of leaves. However, the more leaves you have, the harder the graph will be to read with the naked eye
