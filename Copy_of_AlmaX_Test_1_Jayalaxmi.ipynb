# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaya9522/almabetter_assignments/blob/main/Copy_of_AlmaX_Test_1_Jayalaxmi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Instructions**
#
# ## **1. Attempt all 10 questions in 60 min.**
# ## **2. Open your camera during the test.**
# ## **3. Do not switch the tabs during test.**
# ## **4. Students with plagiarism of codes > 10% (copied from Google or any other student) will not be allowed further in AlmaX placement drives.**
# ## **5. Make sure that you save your test after each code to avoid last minute hustle.**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ![T1.JPG](data:image/jpeg;base64,...)

# %%
# Write you code here
for i in range(52,61+1):
  if i%2 == 0:
    print(i)
# Out:
# 52
# 54
# 56
# 58
# 60

# %% [markdown]
# ![t2.JPG](data:image/jpeg;base64,...)

# %%
# Write you code here

#
name = 'Srivastava'
count = {}
for i in name:
  if i in count:
    count[i] += 1
  elif i not in count:
    count[i]= 1


  
print(f'unique letter in my name are: {count}')
# Out:
# unique letter in my name are: {'S': 1, 'r': 1, 'i': 1, 'v': 2, 'a': 3, 's': 1, 't': 1}

# %% [markdown]
# ![t3.JPG](data:image/jpeg;base64,...)

# %%
# list of team players

team_list = [8,8,8,5,5,4,2,1,3,7,5]
team_dict = {}
# Write you code here
for i in team_list:
  if i not in team_dict:
    team_dict[i] = 1
  elif i in team_dict:
    team_dict[i] += 1

print(team_dict)
# Out:
# {8: 3, 5: 3, 4: 1, 2: 1, 1: 1, 3: 1, 7: 1}

# %% [markdown]
# ![t4n.JPG](data:image/jpeg;base64,...)

# %%
# create dataframe

data = [['xyz', 10], ['abc', 15], ['pzq', 14], ['mnu', 15], ['xyz', 14]]
df= pd.DataFrame(data, columns = ['Name', 'Age'])
df
# Out:
#   Name  Age
# 0  xyz   10
# 1  abc   15
# 2  pzq   14
# 3  mnu   15
# 4  xyz   14

# %%
# Write your code here
df['Age'] = df['Name'].replace(['abc','pzq'],22)

# %%
df['Age']
# Out:
# 0    xyz
# 1     22
# 2     22
# 3    mnu
# 4    xyz
# Name: Age, dtype: object

# %%
df
# Out:
#   Name  Age
# 0  xyz  xyz
# 1  abc   22
# 2  pzq   22
# 3  mnu  mnu
# 4  xyz  xyz

# %% [markdown]
# ## **Q) Print the pattern**
#
# ![T1-pattern.JPG](data:image/jpeg;base64,...)

# %%
# Write you code here
row = 5 
for i in range(1,row+1):
  for j in range (1,i+1):
    print(j*i , end=" ")
  print(" ")
# Out:
# 1
# 2 4
# 3 6 9
# 4 8 12 16
# 5 10 15 20 25

# %% [markdown]
# # **SQL**

# %% [markdown]
# ##**6,7,8) SQL**

# %%
# Install SQlite & Pandasql
# !pip install db-sqlite3
# !pip install pandasql

# Importing Libraries
import pandas as pd
import sqlite3
from pandasql import sqldf
mysql = lambda q: sqldf(q, globals())


# Connection to DataBase
conn = sqlite3.connect('test1_database') 
c = conn.cursor()


# Create table
c.execute('''DROP TABLE IF EXISTS Product;''')

c.execute('''CREATE TABLE Product (
[product_id] INTEGER,
[product_name]  VARCHAR,
[unit_price] INTEGER );''')


          
# Insert data into table          
c.execute('''INSERT INTO Product (product_id, product_name, unit_price) VALUES ('1', 'S8', '1000');''') 
c.execute('''INSERT INTO Product (product_id, product_name, unit_price) VALUES ('2', 'G4', '800');''') 
c.execute('''INSERT INTO Product (product_id, product_name, unit_price) VALUES ('3', 'iPhone', '1400');''') 




# Create table
c.execute('''DROP TABLE IF EXISTS Sales;''')

c.execute('''CREATE TABLE Sales (
[seller_id] INTEGER,
[product_id]  INTEGER,
[buyer_id] INTEGER ,
[sales_date] DATE,
[Quantity] INTEGER,
[price] INTEGER);''')


          
# Insert data into table          
c.execute('''INSERT INTO Sales (seller_id, product_id, buyer_id, sales_date, quantity, price) VALUES ('1', '1', '1', '2019-01-21', '2', '2000');''')
c.execute('''INSERT INTO Sales (seller_id, product_id, buyer_id, sales_date, quantity, price) VALUES ('1', '2', '2', '2019-01-17', '1', '900');''')
c.execute('''INSERT INTO Sales (seller_id, product_id, buyer_id, sales_date, quantity, price) VALUES ('2', '2', '3', '2019-01-02', '1', '800');''')
c.execute('''INSERT INTO Sales (seller_id, product_id, buyer_id, sales_date, quantity, price) VALUES ('3', '3', '4', '2019-01-13', '2', '2800');''') 


conn.commit()


# Get DataFrame

Product = pd.read_sql_query('''SELECT * FROM Product''',conn)
Sales = pd.read_sql_query ('''SELECT * FROM Sales''',conn)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 171 kB 5.1 MB/s
# ...
#   Created wheel for db-sqlite3: filename=db_sqlite3-0.0.1-py3-none-any.whl size=1794 sha256=f42095acc8aacd2e60b3bf273e2637d105f21ead3b978080b9990e2bfbec649e
#   Stored in directory: /root/.cache/pip/wheels/02/38/d5/2f54461050571bf5330fee2a37ab1c9b5e7540b0572f1acdab
# ...
#   Created wheel for db: filename=db-0.1.1-py3-none-any.whl size=3895 sha256=368a96bde44d73c229f0cf18de3cb192ae415085c19478e425d798aa232d7775
#   Stored in directory: /root/.cache/pip/wheels/8e/97/82/741d2b360507411ec233d0280d7371faa94b03bde834e4a9be
# ...
#   Created wheel for antiorm: filename=antiorm-1.2.1-py3-none-any.whl size=31679 sha256=63dd788f4a39ef489691df80409f8cd18ed3e842f2b785511e1e9dab9aee2481
#   Stored in directory: /root/.cache/pip/wheels/c5/43/70/e9729370cfff40c49d3e3d05377d54b3ecd71f64e62341ea80
# Successfully built db-sqlite3 db antiorm
# ...

# %% [markdown]
# **Product Table:**
#
# ![Screenshot 2022-09-22 202612.png](data:image/png;base64,...)
#
# **Sales Table**
#
# ![Screenshot 2022-09-22 202710.png](data:image/png;base64,...)

# %% [markdown]
# **6). Write an SQL query that reports the best seller by total sales price, If there is a tie, report them all.**
#
#
# Result Table
#
# ![Screenshot 2022-09-22 202731.png](data:image/png;base64,...)

# %%
#Write your query here
mysql('''select s.seller_id from Product p join Sales s on s.product_id = p.product_id
order by s.price desc
limit 2''')
# Out:
#    seller_id
# 0          3
# 1          1

# %% [markdown]
# ## **7) Write an SQL query that reports the buyers who have bought S8 but not iPhone. Note that S8 and iPhone are products present in the Product table.**
#
# Expected Output
#
# ![Screenshot 2022-09-22 203436.png](data:image/png;base64,...)

# %%
#Write your query here
mysql('''select s.buyer_id from Product p join Sales s
on s.product_id  = p.product_id
where p.product_name = 'S8' and p.product_name <> 'iPhone' ''')
# Out:
#    buyer_id
# 0         1

# %% [markdown]
# ## **8). Write an SQL query that reports the products that were only sold in spring 2019. That is, between 2019-01-01 and 2019-03-31 inclusive.**
#
# Expected Output
#
# ![Screenshot 2022-09-22 203909.png](data:image/png;base64,...)

# %%
#Write your query here
mysql('''select p.product_id, p.product_name from Product p join Sales s 
on p.product_id = s.product_id
where s.sales_date>= '2019-01-01' and s.sales_date <= '2019-03-3' ''')

# mysql('''select * from Product p join Sales s on s.product_id = p.product_id''')
# Out:
#    product_id product_name  unit_price  seller_id  product_id  buyer_id  \
# 0           1           S8        1000          1           1         1
# 1           2           G4         800          1           2         2
# 2           2           G4         800          2           2         3
# 3           3       iPhone        1400          3           3         4
#
#    sales_date  Quantity  price
# 0  2019-01-21         2   2000
# 1  2019-01-17         1    900
# 2  2019-01-02         1    800
# 3  2019-01-13         2   2800

# %% [markdown]
# ##**9,10) SQL**

# %%
# !pip install db-sqlite3
# !pip install pandasql

# Importing Libraries
import pandas as pd
import sqlite3
from pandasql import sqldf
mysql = lambda q: sqldf(q, globals())


# Connection to DataBase
conn = sqlite3.connect('test_database') 
c = conn.cursor()


c.execute('''DROP TABLE IF EXISTS sales;''')

c.execute('''CREATE TABLE sales (
[sale_id] INTEGER,
[product_id]  INTEGER,
[year] DATE,
[quantity] INTEGER,
[price] INTEGER);''')


          
# Insert data into table          
c.execute('''INSERT INTO sales (sale_id, product_id, year, quantity, price) VALUES ('1', '100', '2008', '10', '5000');''') 
c.execute('''INSERT INTO sales (sale_id, product_id, year, quantity, price) VALUES ('2', '100', '2009', '12', '5000');''') 
c.execute('''INSERT INTO sales (sale_id, product_id, year, quantity, price) VALUES ('7', '200', '2011', '15', '9000');''') 



# Create table
c.execute('''DROP TABLE IF EXISTS products;''')

c.execute('''CREATE TABLE products (
[product_id] INTEGER,
[product_name]  VARCHAR);''')


# Insert data into table          
c.execute('''INSERT INTO products (product_id, product_name) VALUES ('100', 'Nokia');''') 
c.execute('''INSERT INTO products (product_id, product_name) VALUES ('200', 'Apple');''') 
c.execute('''INSERT INTO products (product_id, product_name) VALUES ('300', 'Samsung');''') 


conn.commit()
sales = pd.read_sql_query ('''SELECT * FROM sales''',conn)
products=pd.read_sql_query ('''SELECT * FROM products''',conn)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# **Table 1: sales**
#
# ![image.png](data:image/png;base64,...)
#
# **Table 2: products**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **9). Write an SQL query that returns all product names of the products in the Sales table along with their selling year and price.**
#
# Expected Output:
#
# ![image.png](data:image/png;base64,...)

# %%
#Write your query here
# mysql('''select * from sales s join products p  on s.product_id = p.product_id ''')

mysql('''select p.product_name, s.year, s.price
from sales s join products p on s.product_id = p.product_id''')
# Out:
#   product_name  year  price
# 0        Nokia  2008   5000
# 1        Nokia  2009   5000
# 2        Apple  2011   9000

# %% [markdown]
# ## **10). Write an SQL query that returns the total quantity sold for every product id.**
#
# Expected Output:
#
# ![image.png](data:image/png;base64,...)

# %%
#Write your query here
mysql('''select product_id, sum(quantity) total_quantity
from sales
group by product_id''')
# Out:
#    product_id  total_quantity
# 0         100              22
# 1         200              15
